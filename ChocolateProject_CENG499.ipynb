# %%
import pandas as pd
from matplotlib import pyplot as plt
from collections import Counter
# linear algebra
import numpy as np
import statistics

# data processing
import pandas as pd
import ast
import csv

# data visualization
from matplotlib import pyplot as plt
from matplotlib import style
# %matplotlib inline

# %%
# Our first 10 data.

chocolate = pd.read_csv("/Users/ortacburak/Downloads/flavors_of_cacao-2.csv")
chocolate.head(10)
# Out:
#     Company Specific_Bean_Origin   REF  Review_Date Cocoa_Percent  \
# 0  A. Morin          Agua Grande  1876         2016           63%
# 1  A. Morin                Kpime  1676         2015           70%
# 2  A. Morin               Atsane  1676         2015           70%
# 3  A. Morin                Akata  1680         2015           70%
# 4  A. Morin               Quilla  1704         2015           70%
# 5  A. Morin             Carenero  1315         2014           70%
# 6  A. Morin                 Cuba  1315         2014           70%
# 7  A. Morin         Sur del Lago  1315         2014           70%
# 8  A. Morin       Puerto Cabello  1319         2014           70%
# 9  A. Morin              Pablino  1319         2014           70%
#
#   Company_Location  Rating Bean_Type Broad_Bean_Origin
# 0           France    3.75                    Sao Tome
# 1           France    2.75                        Togo
# 2           France    3.00                        Togo
# ...

# %%
# This is the total chocolate companies in our data.

chocolate.Company.count()
# Out:
# 1795

# %%
# We grouped our the data by the companies and listed here.

chocolate.groupby('Company').count()
# Out:
#                                   Specific_Bean_Origin  REF  Review_Date  \
# Company
# A. Morin                                            23   23           23
# AMMA                                                 5    5            5
# Acalli                                               2    2            2
# Adi                                                  4    4            4
# Aequare (Gianduja)                                   2    2            2
# Ah Cacao                                             1    1            1
# Akesson's (Pralus)                                   3    3            3
# Alain Ducasse                                        5    5            5
# Alexandre                                            4    4            4
# Altus aka Cao Artisan                               10   10           10
# Amano                                                9    9            9
# Amatller (Simon Coll)                                4    4            4
# ...

# %%
# Here, we listed the number of companies in different locations. 

chocolate[['Company','Company_Location']].groupby('Company_Location').count()
# Out:
#                    Company
# Company_Location
# Amsterdam                4
# Argentina                9
# Australia               49
# Austria                 26
# Belgium                 40
# Bolivia                  2
# Brazil                  17
# Canada                 125
# Chile                    2
# Colombia                23
# Costa Rica               9
# Czech Republic           1
# Denmark                 15
# Domincan Republic        5
# Ecuador                 54
# Eucador                  1
# Fiji                     4
# Finland                  2
# France                 156
# Germany                 35
# Ghana                    1
# Grenada                  3
# Guatemala               10
# Honduras                 6
# Hungary                 22
# Iceland                  3
# India                    1
# Ireland                  4
# Israel                   9
# Italy                   63
# Japan                   17
# Lithuania                6
# ...

# %%
# This is the bar graph of the bean type and bean origin. 

chocolate.groupby('Bean_Type')['Broad_Bean_Origin'].count().plot.bar(width=2, figsize=(15, 6))

y_pos=[0,1,5,8,9]
plt
# Out:
# <module 'matplotlib.pyplot' from '/Users/ortacburak/anaconda3/lib/python3.7/site-packages/matplotlib/pyplot.py'>

# %%
# This is the graph of the bean type. It can be seen that "Criollo" is the most popular bean type.

sns.countplot(y='Bean_Type',data=chocolate)

# %%
# We showed the number of chocolates which has greater than 3.5 rating point.

majorChocolates = chocolate[chocolate.Rating>3.5]
print(len(majorChocolates), "Chocolates which has more than 3.5 point")
# Out:
# 310 Chocolates which has more than 3.5 point

# %%
# After getting the number of chocolates which has greater than 3.5 rating point,
# We showed the average of their ratings.

avg_rate_major_chocolates = chocolate[chocolate.Rating > 3.5].Rating.mean()
print('Average rating of chocolates with more than 3.5 point:', str("%8.4f" % avg_rate_major_chocolates))
# Out:
# Average rating of chocolates with more than 3.5 point:   3.8371

# %%
# This is the graph of the major chocolates which has greater than 3.5 rating point.

avg_rating=majorChocolates.groupby('Company')['Rating'].agg(['mean'])
avg_rating.plot(figsize=(15, 6))

# %%
# This also another graph to show the rating distribution between the companies.

n, bins, patches = plt.hist(majorChocolates['Rating'])
plt.show()

# %%
# We showed the the date of the review for companies. Therefore, most of the reviews are actually from 2011 to 2016.

chocolate[['Company','Review_Date']].groupby(['Review_Date']).size().plot.barh()

# %%
# Cocoa percent is very important for a tasty chocolate!
# Here is the cocoa percentage graph. Many companies has 70% cocoa percent in their chocolates!

chocolate[['Company','Cocoa_Percent',]].groupby(['Cocoa_Percent']).size().plot.barh(figsize=(15, 10))

# %%
# Here is the company distribution by the company location in our data. 
# It can be clearly seen that most of the companies are from U.S.A

d = chocolate[['Company','Company_Location']].groupby('Company_Location').count()
d.plot.pie(subplots=True, figsize=(15, 15))
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x1a1c0ca2b0>],
#       dtype=object)

# %%
# This is how we calculate the correlation matrix
corr = chocolate.corr()

# This is how we plot the heatmap
sns.heatmap(corr, 
        xticklabels=corr.columns,
        yticklabels=corr.columns)
